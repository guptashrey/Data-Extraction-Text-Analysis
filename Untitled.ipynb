# %%
import nltk

# %%
# load data
filename = 'data/0000004457-00-000018.txt'
file = open(filename, 'rt')
text = file.read()
file.close()
# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]
# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]
# filter out stop words
# from nltk.corpus import stopwords
# stop_words = set(stopwords.words('english'))
# words = [w for w in words if not w in stop_words]
# print(words[:100])

# %%
words
# Out:
# ['begin',
#  'privacyenhanced',
#  'message',
#  'proctype',
#  'micclear',
#  'originatorname',
#  'webmaster',
#  'wwwsecgov',
#  'originatorkeyasymmetric',
#  'micinfo',
#  'rsa',
#  'secdocument',
#  'secheader',
#  'accession',
#  'number',
#  'conformed',
#  'submission',
#  'type',
#  'public',
#  'document',
#  'count',
#  'conformed',
#  'period',
#  'of',
#  'report',
#  'filed',
#  'as',
#  'of',
#  'date',
#  'filer',
#  'company',
#  'data',
#  'company',
#  'conformed',
#  'name',
#  'amerco',
#  'nv',
#  'central',
#  'index',
#  'key',
#  'standard',
#  'industrial',
#  'classification',
#  'servicesauto',
#  'rental',
#  'leasing',
#  'no',
#  'drivers',
#  'irs',
#  'number',
#  'state',
#  'of',
#  'incorporation',
#  'nv',
#  'fiscal',
#  'year',
#  'end',
#  'filing',
#  'values',
#  'form',
#  'type',
#  'sec',
#  'act',
#  'sec',
#  'file',
#  'number',
#  'film',
#  'number',
#  'business',
#  'address',
#  'street',
#  'airmotive',
#  'wy',
#  'ste',
#  'city',
#  'reno',
#  'state',
#  'nv',
#  'zip',
#  'business',
#  'phone',
#  'mail',
#  'address',
#  'street',
#  'airmotive',
#  'way',
#  'street',
#  'suite',
#  'city',
#  'reno',
#  'state',
#  'nv',
#  'zip',
#  'former',
#  'company',
#  'former',
#  'conformed',
#  'name',
#  'amerco',
#  'date',
#  'of',
#  'name',
#  'change',
#  'secheader',
#  'document',
#  'type',
#  'sequence',
#  'description',
#  'form',
#  'text',
#  'page',
#  'united',
#  'states',
#  'securities',
#  'and',
#  'exchange',
#  'commission',
#  'washington',
#  'dc',
#  'form',
#  'mark',
#  'one',
#  'x',
#  'quarterly',
#  'report',
#  'pursuant',
#  'to',
#  'section',
#  'or',
#  'd',
#  'of',
#  'the',
#  'securities',
#  'exchange',
#  'act',
#  'of',
#  'for',
#  'the',
#  'quarterly',
#  'period',
#  'ended',
#  'december',
#  'or',
#  'transition',
#  'report',
#  'pursuant',
#  'to',
#  'section',
#  'or',
#  'd',
#  'of',
#  'the',
#  'securities',
#  'exchange',
#  'act',
#  'of',
#  'for',
#  'the',
#  'transition',
#  'period',
#  'from',
#  'to',
#  'commission',
#  'registrant',
#  'state',
#  'of',
#  'incorporation',
#  'irs',
#  'employer',
#  'file',
#  'number',
#  'address',
#  'and',
#  'telephone',
#  'number',
#  'identification',
#  'no',
#  'amerco',
#  'a',
#  'nevada',
#  'corporation',
#  'airmotive',
#  'way',
#  'ste',
#  'reno',
#  'nevada',
#  'telephone',
#  'uhaul',
#  'international',
#  'inc',
#  'a',
#  'nevada',
#  'corporation',
#  'n',
#  'central',
#  'avenue',
#  'phoenix',
#  'arizona',
#  'telephone',
#  'indicate',
#  'by',
#  'check',
#  'mark',
#  'whether',
#  'the',
#  'registrant',
#  'has',
#  'filed',
#  'all',
#  'reports',
#  'required',
#  'to',
#  'be',
#  'filed',
#  'by',
#  'section',
#  'or',
#  'd',
#  'of',
#  'the',
#  'securities',
#  'exchange',
#  'act',
#  'of',
#  'during',
#  'the',
#  'preceding',
#  'months',
#  'or',
#  'for',
#  'such',
#  'shorter',
#  'period',
#  'that',
#  'the',
#  'registrant',
#  'was',
#  'required',
#  'to',
#  'file',
#  'such',
#  'reports',
#  'and',
#  'has',
#  'been',
#  'subject',
#  'to',
#  'such',
#  'filing',
#  'requirements',
#  'for',
#  'the',
#  'past',
#  'days',
#  'yes',
#  'x',
#  'no',
#  'shares',
#  'of',
#  'amerco',
#  'common',
#  'stock',
#  'par',
#  'value',
#  'were',
#  'outstanding',
#  'at',
#  'february',
#  'shares',
#  'of',
#  'uhaul',
#  'international',
#  'inc',
#  'common',
#  'stock',
#  'par',
#  'value',
#  'were',
#  'outstanding',
#  'at',
#  'february',
#  'uhaul',
#  'international',
#  'inc',
#  'meets',
#  'the',
#  'conditions',
#  'set',
#  'forth',
#  'in',
#  'general',
#  'instruction',
#  'h',
#  'a',
#  'and',
#  'b',
#  'of',
#  'form',
#  'and',
#  'is',
#  'therefore',
#  'filing',
#  'this',
#  'form',
#  'with',
#  'the',
#  'reduced',
#  'disclosure',
#  'format',
#  'page',
#  'table',
#  'of',
#  'contents',
#  'part',
#  'i',
#  'financial',
#  'information',
#  'item',
#  'financial',
#  'statements',
#  'a',
#  'consolidated',
#  'balance',
#  'sheets',
#  'as',
#  'of',
#  'december',
#  'and',
#  'march',
#  'b',
#  'consolidated',
#  'statements',
#  'of',
#  'earnings',
#  'for',
#  'the',
#  'nine',
#  'months',
#  'ended',
#  'december',
#  'and',
#  'c',
#  'consolidated',
#  'statements',
#  'of',
#  'changes',
#  'in',
#  'stockholders',
#  'equity',
#  'for',
#  'the',
#  'nine',
#  'months',
#  'ended',
#  'december',
#  'd',
#  'consolidated',
#  'statements',
#  'of',
#  'comprehensive',
#  'income',
#  'for',
#  'the',
#  'nine',
#  'months',
#  'ended',
#  'december',
#  'and',
#  'e',
#  'consolidated',
#  'statements',
#  'of',
#  'earnings',
#  'for',
#  'the',
#  'quarters',
#  'ended',
#  'december',
#  'and',
#  'f',
#  'consolidated',
#  'statements',
#  'of',
#  'cash',
#  'flows',
#  'for',
#  'the',
#  'nine',
#  'months',
#  'ended',
#  'december',
#  'and',
#  'g',
#  'notes',
#  'to',
#  'consolidated',
#  'financial',
#  'statements',
#  'december',
#  'march',
#  'and',
#  'december',
#  'item',
#  'management',
#  's',
#  'discussion',
#  'and',
#  'analysis',
#  'of',
#  'financial',
#  'condition',
#  'and',
#  'results',
#  'of',
#  'operations',
#  'item',
#  'quantitative',
#  'and',
#  'qualitative',
#  'disclosures',
#  'about',
#  'market',
#  'risk',
#  'part',
#  'ii',
#  'other',
#  'information',
#  'item',
#  'legal',
#  'proceedings',
#  'item',
#  'exhibits',
#  'and',
#  'reports',
#  'on',
#  'form',
#  'page',
#  'this',
#  'page',
#  'left',
#  'intentionally',
#  'blank',
#  'page',
#  'part',
#  'i',
#  'financial',
#  'information',
#  'item',
#  'financial',
#  'statements',
#  'amerco',
#  'and',
#  'consolidated',
#  'subsidiaries',
#  'consolidated',
#  'balance',
#  'sheets',
#  'december',
#  'march',
#  'assets',
#  'unaudited',
#  'in',
#  'thousands',
#  'cash',
#  'and',
#  'cash',
#  'equivalents',
#  'trade',
#  'receivables',
#  'net',
#  'notes',
#  'and',
#  'mortgage',
#  'receivables',
#  'net',
#  'inventories',
#  'net',
#  'prepaid',
#  'expenses',
#  'investments',
#  'fixed',
#  'maturities',
#  'investments',
#  'other',
#  'deferred',
#  'policy',
#  'acquisition',
#  'costs',
#  'other',
#  'assets',
#  'property',
#  'plant',
#  'and',
#  'equipment',
#  'at',
#  'cost',
#  'land',
#  'buildings',
#  'and',
#  'improvements',
#  'furniture',
#  'and',
#  'equipment',
#  'rental',
#  'trailers',
#  'and',
#  'other',
#  'rental',
#  'equipment',
#  'rental',
#  'trucks',
#  'less',
#  'accumulated',
#  'depreciation',
#  'total',
#  'property',
#  'plant',
#  'and',
#  'equipment',
#  'total',
#  'assets',
#  'the',
#  'accompanying',
#  'notes',
#  'are',
#  'an',
#  'integral',
#  'part',
#  'of',
#  'these',
#  'consolidated',
#  'financial',
#  'statements',
#  'page',
#  'december',
#  'march',
#  'liabilities',
#  'and',
#  'stockholders',
#  'equity',
#  'unaudited',
#  'in',
#  'thousands',
#  'except',
#  'share',
#  'and',
#  'per',
#  'share',
#  'data',
#  'liabilities',
#  'accounts',
#  'payable',
#  'and',
#  'accrued',
#  'expenses',
#  'notes',
#  'and',
#  'loans',
#  'payable',
#  'policy',
#  'benefits',
#  'and',
#  'losses',
#  'claims',
#  'and',
#  'loss',
#  'expenses',
#  'payable',
#  'liabilities',
#  'from',
#  'premium',
#  'deposits',
#  'cash',
#  'overdraft',
#  'other',
#  'policyholders',
#  'funds',
#  'and',
#  'liabilities',
#  'deferred',
#  'income',
#  'deferred',
#  'income',
#  'taxes',
#  'stockholders',
#  'equity',
#  'serial',
#  'preferred',
#  'stock',
#  'with',
#  'or',
#  'without',
#  'par',
#  'value',
#  'shares',
#  'authorized',
#  'series',
#  'a',
#  'preferred',
#  'stock',
#  'with',
#  'no',
#  'par',
#  'value',
#  'shares',
#  'authorized',
#  'issued',
#  'and',
#  'outstanding',
#  'as',
#  'of',
#  'december',
#  'and',
#  'march',
#  'series',
#  'b',
#  'preferred',
#  'stock',
#  'with',
#  'no',
#  'par',
#  'value',
#  'shares',
#  'authorized',
#  'none',
#  'and',
#  'shares',
#  'outstanding',
#  'as',
#  'of',
#  'december',
#  'and',
#  'march',
#  'respectively',
#  'serial',
#  'common',
#  'stock',
#  'with',
#  'or',
#  'without',
#  'par',
#  'value',
#  'shares',
#  'authorized',
#  'series',
#  'a',
#  'common',
#  'stock',
#  'of',
#  'par',
#  'value',
#  'shares',
#  'authorized',
#  'shares',
#  'issued',
#  'as',
#  'of',
#  'december',
#  'and',
#  'march',
#  'common',
#  'stock',
#  'of',
#  'par',
#  'value',
#  'shares',
#  'authorized',
#  'shares',
#  'issued',
#  'as',
#  'of',
#  'december',
#  'and',
#  'march',
#  'additional',
#  'paidin',
#  'capital',
#  'accumulated',
#  'other',
#  'comprehensive',
#  'income',
#  'retained',
#  'earnings',
#  'less',
#  'cost',
#  'of',
#  'common',
#  'shares',
#  'in',
#  'treasury',
#  'net',
#  'shares',
#  'as',
#  'of',
#  'december',
#  'and',
#  'march',
#  'unearned',
#  'employee',
#  'stock',
#  'ownership',
#  'plan',
#  'shares',
#  'total',
#  'stockholders',
#  'equity',
#  'contingent',
#  'liabilities',
#  'and',
#  'commitments',
#  'total',
#  'liabilities',
#  'and',
#  'stockholders',
#  'equity',
#  'the',
#  'accompanying',
#  'notes',
#  'are',
#  'an',
#  'integral',
#  'part',
#  'of',
#  'these',
#  'consolidated',
#  'financial',
#  'statements',
#  'page',
#  'amerco',
#  'and',
#  'consolidated',
#  'subsidiaries',
#  'consolidated',
#  'statements',
#  'of',
#  'earnings',
#  'nine',
#  'months',
#  'ended',
#  'december',
#  'unaudited',
#  'in',
#  'thousands',
#  'except',
#  'share',
#  'and',
#  'per',
#  'share',
#  'data',
#  'revenues',
#  'rental',
#  'revenue',
#  'net',
#  'sales',
#  'premiums',
#  'net',
#  'investment',
#  'and',
#  'interest',
#  'income',
#  'total',
#  'revenues',
#  'costs',
#  'and',
#  'expenses',
#  'operating',
#  'expenses',
#  'cost',
#  'of',
#  'sales',
#  'benefits',
#  'and',
#  'losses',
#  'amortization',
#  'of',
#  'deferred',
#  'acquisition',
#  'costs',
#  'lease',
#  'expense',
#  'depreciation',
#  'net',
#  'total',
#  'costs',
#  'and',
#  'expenses',
#  'earnings',
#  'from',
#  'operations',
#  'interest',
#  'expense',
#  'pretax',
#  'earnings',
#  'income',
#  'tax',
#  'expense',
#  'net',
#  'earnings',
#  'earnings',
#  'per',
#  'common',
#  'share',
#  'basic',
#  'diluted',
#  'weighted',
#  'average',
#  'common',
#  'shares',
#  'outstanding',
#  'basic',
#  'diluted',
#  'the',
#  'accompanying',
#  'notes',
#  'are',
#  'an',
#  'integral',
#  'part',
#  'of',
#  'these',
#  'consolidated',
#  'financial',
#  'statements',
#  'page',
#  'amerco',
#  'and',
#  'consolidated',
#  'subsidiaries',
#  'consolidated',
#  'statements',
#  'of',
#  'changes',
#  'in',
#  'stockholders',
#  'equity',
#  'nine',
#  'months',
#  'ended',
#  'december',
#  'unaudited',
#  'in',
#  'thousands',
#  'except',
#  'share',
#  'and',
#  'per',
#  'share',
#  'data',
#  'series',
#  'a',
#  'common',
#  'stock',
#  'of',
#  'par',
#  'value',
#  'shares',
#  'authorized',
#  'shares',
#  'issued',
#  'as',
#  'of',
#  'december',
#  'beginning',
#  'and',
#  'end',
#  'of',
#  'period',
#  'common',
#  'stock',
#  'of',
#  'par',
#  'value',
#  'shares',
#  'authorized',
#  'shares',
#  'issued',
#  'as',
#  'of',
#  'december',
#  'beginning',
#  'and',
#  'end',
#  'of',
#  'period',
#  'additional',
#  'paidin',
#  'capital',
#  'beginning',
#  'of',
#  'period',
#  'preferred',
#  'stock',
#  'repurchase',
#  'issuance',
#  'of',
#  'common',
#  'shares',
#  'under',
#  'leveraged',
#  'employee',
#  'stock',
#  'ownership',
#  'plan',
#  'end',
#  'of',
#  'period',
#  'accumulated',
#  'other',
#  'comprehensive',
#  'income',
#  'beginning',
#  'of',
#  'period',
#  'foreign',
#  'currency',
#  'translation',
#  'fair',
#  'market',
#  'value',
#  'of',
#  'cash',
#  'flow',
#  'hedge',
#  'unrealized',
#  'loss',
#  'on',
#  'investments',
#  'end',
#  'of',
#  'period',
#  'retained',
#  'earnings',
#  'beginning',
#  'of',
#  'period',
#  'net',
#  'earnings',
#  'preferred',
#  'stock',
#  'dividends',
#  'paid',
#  'series',
#  'a',
#  'per',
#  'share',
#  'series',
#  'b',
#  'per',
#  'share',
#  'end',
#  'of',
#  'period',
#  'less',
#  'treasury',
#  'stock',
#  'beginning',
#  'and',
#  'end',
#  'of',
#  'period',
#  'less',
#  'unearned',
#  'employee',
#  'stock',
#  'ownership',
#  'plan',
#  'shares',
#  'beginning',
#  'of',
#  'period',
#  'purchase',
#  'of',
#  'shares',
#  'repayments',
#  'from',
#  'loan',
#  'end',
#  'of',
#  'year',
#  'total',
#  'stockholders',
#  'equity',
#  'the',
#  'accompanying',
#  'notes',
#  'are',
#  'an',
#  'integral',
#  'part',
#  'of',
#  'these',
#  'consolidated',
#  'financial',
#  'statements',
#  'page',
#  'amerco',
#  'and',
#  'consolidated',
#  'subsidiaries',
#  'consolidated',
#  ...]

# %%
filename = 'stopwords/StopWords_Generic.txt'
file = open(filename, 'rt')
stop_words = file.read()
file.close()

# %%
tokens1 = word_tokenize(stop_words)
tokens1 = [w.lower() for w in tokens1]

# %%
words = [w for w in words if not w in stop_words]
print(words)
# Out:
# ['begin', 'privacyenhanced', 'message', 'proctype', 'micclear', 'originatorname', 'webmaster', 'wwwsecgov', 'originatorkeyasymmetric', 'micinfo', 'rsa', 'secdocument', 'secheader', 'accession', 'number', 'conformed', 'submission', 'type', 'public', 'document', 'count', 'conformed', 'period', 'of', 'report', 'filed', 'as', 'of', 'date', 'filer', 'company', 'data', 'company', 'conformed', 'name', 'amerco', 'nv', 'central', 'index', 'key', 'standard', 'industrial', 'classification', 'servicesauto', 'rental', 'leasing', 'no', 'drivers', 'irs', 'number', 'state', 'of', 'incorporation', 'nv', 'fiscal', 'year', 'end', 'filing', 'values', 'form', 'type', 'sec', 'act', 'sec', 'file', 'number', 'film', 'number', 'business', 'address', 'street', 'airmotive', 'wy', 'ste', 'city', 'reno', 'state', 'nv', 'zip', 'business', 'phone', 'mail', 'address', 'street', 'airmotive', 'way', 'street', 'suite', 'city', 'reno', 'state', 'nv', 'zip', 'former', 'company', 'former', 'conformed', 'name', 'amerco', 'date', 'of', 'name', 'change', 'secheader', 'document', 'type', 'sequence', 'description', 'form', 'text', 'page', 'united', 'states', 'securities', 'and', 'exchange', 'commission', 'washington', 'dc', 'form', 'mark', 'one', 'x', 'quarterly', 'report', 'pursuant', 'to', 'section', 'or', 'd', 'of', 'the', 'securities', 'exchange', 'act', 'of', 'for', 'the', 'quarterly', 'period', 'ended', 'december', 'or', 'transition', 'report', 'pursuant', 'to', 'section', 'or', 'd', 'of', 'the', 'securities', 'exchange', 'act', 'of', 'for', 'the', 'transition', 'period', 'from', 'to', 'commission', 'registrant', 'state', 'of', 'incorporation', 'irs', 'employer', 'file', 'number', 'address', 'and', 'telephone', 'number', 'identification', 'no', 'amerco', 'a', 'nevada', 'corporation', 'airmotive', 'way', 'ste', 'reno', 'nevada', 'telephone', 'uhaul', 'international', 'inc', 'a', 'nevada', 'corporation', 'n', 'central', 'avenue', 'phoenix', 'arizona', 'telephone', 'indicate', 'by', 'check', 'mark', 'whether', 'the', 'registrant', 'has', 'filed', 'all', 'reports', 'required', 'to', 'be', 'filed', 'by', 'section', 'or', 'd', 'of', 'the', 'securities', 'exchange', 'act', 'of', 'during', 'the', 'preceding', 'months', 'or', 'for', 'such', 'shorter', 'period', 'that', 'the', 'registrant', 'was', 'required', 'to', 'file', 'such', 'reports', 'and', 'has', 'been', 'subject', 'to', 'such', 'filing', 'requirements', 'for', 'the', 'past', 'days', 'yes', 'x', 'no', 'shares', 'of', 'amerco', 'common', 'stock', 'par', 'value', 'were', 'outstanding', 'at', 'february', 'shares', 'of', 'uhaul', 'international', 'inc', 'common', 'stock', 'par', 'value', 'were', 'outstanding', 'at', 'february', 'uhaul', 'international', 'inc', 'meets', 'the', 'conditions', 'set', 'forth', 'in', 'general', 'instruction', 'h', 'a', 'and', 'b', 'of', 'form', 'and', 'is', 'therefore', 'filing', 'this', 'form', 'with', 'the', 'reduced', 'disclosure', 'format', 'page', 'table', 'of', 'contents', 'part', 'i', 'financial', 'information', 'item', 'financial', 'statements', 'a', 'consolidated', 'balance', 'sheets', 'as', 'of', 'december', 'and', 'march', 'b', 'consolidated', 'statements', 'of', 'earnings', 'for', 'the', 'nine', 'months', 'ended', 'december', 'and', 'c', 'consolidated', 'statements', 'of', 'changes', 'in', 'stockholders', 'equity', 'for', 'the', 'nine', 'months', 'ended', 'december', 'd', 'consolidated', 'statements', 'of', 'comprehensive', 'income', 'for', 'the', 'nine', 'months', 'ended', 'december', 'and', 'e', 'consolidated', 'statements', 'of', 'earnings', 'for', 'the', 'quarters', 'ended', 'december', 'and', 'f', 'consolidated', 'statements', 'of', 'cash', 'flows', 'for', 'the', 'nine', 'months', 'ended', 'december', 'and', 'g', 'notes', 'to', 'consolidated', 'financial', 'statements', 'december', 'march', 'and', 'december', 'item', 'management', 's', 'discussion', 'and', 'analysis', 'of', 'financial', 'condition', 'and', 'results', 'of', 'operations', 'item', 'quantitative', 'and', 'quali ...

# %%
# Import pandas
import pandas as pd

# Assign spreadsheet filename to `file`
file = 'masterdictionary/LoughranMcDonald_MasterDictionary_2016.xlsx'
# Load spreadsheet
xl = pd.ExcelFile(file)
# Print the sheet names
print(xl.sheet_names)
# Out:
# ['LoughranMcDonald_MasterDictiona']

# %%
import numpy as np
# Load a sheet into a DataFrame by name: df1
df1 = xl.parse('LoughranMcDonald_MasterDictiona')
df1 = df1[['Word', 'Negative', 'Positive']]
df1.replace(0, np.nan, inplace=True)

# %%
list_of_words = df1['Word'].tolist()
result_words = []
len(list_of_words)
for i in range(len(list_of_words)):
    result_words.append([str(list_of_words[i]).lower(),i])
list_of_words = result_words

# %%
list_of_words[0][0]
# Out:
# 'aardvark'

# %%
positive = 0
negative = 0
for temp_word in words:
    flag = False
    for i in range(85221):
        if temp_word in list_of_words[i]:
            flag = True
            break
    if flag:
        print(temp_word)
        if not math.isnan(df1.iloc[i]['Positive']):
            positive = positive + 1
            print("'{}' is positive".format(temp_word.upper()))
        if not math.isnan(df1.iloc[i]['Negative']):
            negative = negative - 1
            print("'{}' is negative".format(temp_word.upper()))
    else:
        print("'{}' is neither positive nor negative".format(temp_word.upper()))
        
print('Positive Score: {}'.format(positive))
print('Negative Score: {}'.format(negative))
# Out:
# begin
# 'PRIVACYENHANCED' is neither positive nor negative
# message
# 'PROCTYPE' is neither positive nor negative
# 'MICCLEAR' is neither positive nor negative
# 'ORIGINATORNAME' is neither positive nor negative
# webmaster
# 'WWWSECGOV' is neither positive nor negative
# 'ORIGINATORKEYASYMMETRIC' is neither positive nor negative
# 'MICINFO' is neither positive nor negative
# 'RSA' is neither positive nor negative
# 'SECDOCUMENT' is neither positive nor negative
# 'SECHEADER' is neither positive nor negative
# accession
# number
# conformed
# submission
# type
# public
# document
# count
# conformed
# period
# of
# report
# filed
# as
# of
# date
# filer
# company
# data
# company
# conformed
# name
# 'AMERCO' is neither positive nor negative
# 'NV' is neither positive nor negative
# central
# index
# key
# standard
# industrial
# classification
# 'SERVICESAUTO' is neither positive nor negative
# rental
# leasing
# no
# drivers
# 'IRS' is neither positive nor negative
# number
# state
# of
# incorporation
# 'NV' is neither positive nor negative
# fiscal
# year
# end
# filing
# values
# form
# type
# sec
# act
# sec
# file
# number
# film
# number
# business
# address
# street
# 'AIRMOTIVE' is neither positive nor negative
# 'WY' is neither positive nor negative
# 'STE' is neither positive nor negative
# city
# 'RENO' is neither positive nor negative
# state
# 'NV' is neither positive nor negative
# zip
# business
# phone
# mail
# address
# street
# 'AIRMOTIVE' is neither positive nor negative
# way
# street
# suite
# city
# 'RENO' is neither positive nor negative
# state
# 'NV' is neither positive nor negative
# zip
# former
# company
# former
# conformed
# name
# 'AMERCO' is neither positive nor negative
# date
# of
# name
# change
# 'SECHEADER' is neither positive nor negative
# document
# type
# sequence
# description
# form
# text
# page
# united
# states
# securities
# and
# exchange
# commission
# 'WASHINGTON' is neither positive nor negative
# 'DC' is neither positive nor negative
# form
# mark
# one
# 'X' is neither positive nor negative
# quarterly
# report
# pursuant
# to
# section
# or
# 'D' is neither positive nor negative
# of
# the
# securities
# exchange
# act
# of
# for
# the
# quarterly
# period
# ended
# 'DECEMBER' is neither positive nor negative
# or
# transition
# report
# pursuant
# to
# section
# or
# 'D' is neither positive nor negative
# of
# the
# securities
# exchange
# act
# of
# for
# the
# transition
# period
# from
# to
# commission
# registrant
# state
# of
# incorporation
# 'IRS' is neither positive nor negative
# employer
# file
# number
# address
# and
# telephone
# number
# identification
# no
# 'AMERCO' is neither positive nor negative
# 'A' is neither positive nor negative
# 'NEVADA' is neither positive nor negative
# corporation
# 'AIRMOTIVE' is neither positive nor negative
# way
# 'STE' is neither positive nor negative
# 'RENO' is neither positive nor negative
# 'NEVADA' is neither positive nor negative
# telephone
# 'UHAUL' is neither positive nor negative
# international
# 'INC' is neither positive nor negative
# 'A' is neither positive nor negative
# 'NEVADA' is neither positive nor negative
# corporation
# 'N' is neither positive nor negative
# central
# avenue
# phoenix
# 'ARIZONA' is neither positive nor negative
# telephone
# indicate
# by
# check
# mark
# whether
# the
# registrant
# has
# filed
# all
# reports
# required
# to
# be
# filed
# by
# section
# or
# 'D' is neither positive nor negative
# of
# the
# securities
# exchange
# act
# of
# during
# the
# preceding
# months
# or
# for
# such
# shorter
# period
# that
# the
# registrant
# was
# required
# to
# file
# such
# reports
# and
# has
# been
# subject
# to
# such
# filing
# requirements
# for
# the
# past
# days
# yes
# 'X' is neither positive nor negative
# no
# shares
# of
# 'AMERCO' is neither positive nor negative
# common
# stock
# par
# value
# were
# outstanding
# at
# 'FEBRUARY' is neither positive nor negative
# shares
# of
# 'UHAUL' is neither positive nor negative
# international
# 'INC' is neither positive nor negative
# common
# stock
# par
# value
# were
# outstanding
# at
# 'FEBRUARY' is neither positive nor negative
# 'UHAUL' is neither positive nor negative
# international
# 'INC' is neither positive nor negative
# meets
# the
# conditions
# set
# forth
# in
# general
# instruction
# 'H' is neither positive nor negative
# 'A' is neither positive nor negative
# and
# 'B' is neither positive nor negative
# of
# form
# and
# is
# therefore
# filing
# this
# form
# with
# the
# reduced
# disclosure
# format
# page
# table
# of
# contents
# part
# 'I' is neither positive nor negative
# financial
# information
# item
# financial
# statements
# 'A' is neither positive nor negative
# consolidated
# balance
# sheets
# as
# of
# 'DECEMBER' is neither positive nor negative
# and
# march
# 'B' is neither positive nor negative
# consolidated
# statements
# of
# earnings
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# 'C' is neither positive nor negative
# consolidated
# statements
# of
# changes
# in
# stockholders
# equity
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# 'D' is neither positive nor negative
# consolidated
# statements
# of
# comprehensive
# income
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# 'E' is neither positive nor negative
# consolidated
# statements
# of
# earnings
# for
# the
# quarters
# ended
# 'DECEMBER' is neither positive nor negative
# and
# 'F' is neither positive nor negative
# consolidated
# statements
# of
# cash
# flows
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# 'G' is neither positive nor negative
# notes
# to
# consolidated
# financial
# statements
# 'DECEMBER' is neither positive nor negative
# march
# and
# 'DECEMBER' is neither positive nor negative
# item
# management
# 'S' is neither positive nor negative
# discussion
# and
# analysis
# of
# financial
# condition
# and
# results
# of
# operations
# item
# quantitative
# and
# qualitative
# disclosures
# about
# market
# risk
# part
# 'II' is neither positive nor negative
# other
# information
# item
# legal
# proceedings
# item
# exhibits
# and
# reports
# on
# form
# page
# this
# page
# left
# intentionally
# blank
# page
# part
# 'I' is neither positive nor negative
# financial
# information
# item
# financial
# statements
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# consolidated
# balance
# sheets
# 'DECEMBER' is neither positive nor negative
# march
# assets
# unaudited
# in
# thousands
# cash
# and
# cash
# equivalents
# trade
# receivables
# net
# notes
# and
# mortgage
# receivables
# net
# inventories
# net
# prepaid
# expenses
# investments
# fixed
# maturities
# investments
# other
# deferred
# policy
# acquisition
# costs
# other
# assets
# property
# plant
# and
# equipment
# at
# cost
# land
# buildings
# and
# improvements
# 'IMPROVEMENTS' is positive
# furniture
# and
# equipment
# rental
# trailers
# and
# other
# rental
# equipment
# rental
# trucks
# less
# accumulated
# depreciation
# total
# property
# plant
# and
# equipment
# total
# assets
# the
# accompanying
# notes
# are
# an
# integral
# part
# of
# these
# consolidated
# financial
# statements
# page
# 'DECEMBER' is neither positive nor negative
# march
# liabilities
# and
# stockholders
# equity
# unaudited
# in
# thousands
# except
# share
# and
# per
# share
# data
# liabilities
# accounts
# payable
# and
# accrued
# expenses
# notes
# and
# loans
# payable
# policy
# benefits
# and
# losses
# 'LOSSES' is negative
# claims
# 'CLAIMS' is negative
# and
# loss
# 'LOSS' is negative
# expenses
# payable
# liabilities
# from
# premium
# deposits
# cash
# overdraft
# other
# policyholders
# funds
# and
# liabilities
# deferred
# income
# deferred
# income
# taxes
# stockholders
# equity
# serial
# preferred
# stock
# with
# or
# without
# par
# value
# shares
# authorized
# series
# 'A' is neither positive nor negative
# preferred
# stock
# with
# no
# par
# value
# shares
# authorized
# issued
# and
# outstanding
# as
# of
# 'DECEMBER' is neither positive nor negative
# and
# march
# series
# 'B' is neither positive nor negative
# preferred
# stock
# with
# no
# par
# value
# shares
# authorized
# none
# and
# shares
# outstanding
# as
# of
# 'DECEMBER' is neither positive nor negative
# and
# march
# respectively
# serial
# common
# stock
# with
# or
# without
# par
# value
# shares
# authorized
# series
# 'A' is neither positive nor negative
# common
# stock
# of
# par
# value
# shares
# authorized
# shares
# issued
# as
# of
# 'DECEMBER' is neither positive nor negative
# and
# march
# common
# stock
# of
# par
# value
# shares
# authorized
# shares
# issued
# as
# of
# 'DECEMBER' is neither positive nor negative
# and
# march
# additional
# 'PAIDIN' is neither positive nor negative
# capital
# accumulated
# other
# comprehensive
# income
# retained
# earnings
# less
# cost
# of
# common
# shares
# in
# treasury
# net
# shares
# as
# of
# 'DECEMBER' is neither positive nor negative
# and
# march
# unearned
# employee
# stock
# ownership
# plan
# shares
# total
# stockholders
# equity
# contingent
# liabilities
# and
# commitments
# total
# liabilities
# and
# stockholders
# equity
# the
# accompanying
# notes
# are
# an
# integral
# part
# of
# these
# consolidated
# financial
# statements
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# consolidated
# statements
# of
# earnings
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# unaudited
# in
# thousands
# except
# share
# and
# per
# share
# data
# revenues
# rental
# revenue
# net
# sales
# premiums
# net
# investment
# and
# interest
# income
# total
# revenues
# costs
# and
# expenses
# operating
# expenses
# cost
# of
# sales
# benefits
# and
# losses
# 'LOSSES' is negative
# amortization
# of
# deferred
# acquisition
# costs
# lease
# expense
# depreciation
# net
# total
# costs
# and
# expenses
# earnings
# from
# operations
# interest
# expense
# pretax
# earnings
# income
# tax
# expense
# net
# earnings
# earnings
# per
# common
# share
# basic
# diluted
# weighted
# average
# common
# shares
# outstanding
# basic
# diluted
# the
# accompanying
# notes
# are
# an
# integral
# part
# of
# these
# consolidated
# financial
# statements
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# consolidated
# statements
# of
# changes
# in
# stockholders
# equity
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# unaudited
# in
# thousands
# except
# share
# and
# per
# share
# data
# series
# 'A' is neither positive nor negative
# common
# stock
# of
# par
# value
# shares
# authorized
# shares
# issued
# as
# of
# 'DECEMBER' is neither positive nor negative
# beginning
# and
# end
# of
# period
# common
# stock
# of
# par
# value
# shares
# authorized
# shares
# issued
# as
# of
# 'DECEMBER' is neither positive nor negative
# beginning
# and
# end
# of
# period
# additional
# 'PAIDIN' is neither positive nor negative
# capital
# beginning
# of
# period
# preferred
# stock
# repurchase
# issuance
# of
# common
# shares
# under
# leveraged
# employee
# stock
# ownership
# plan
# end
# of
# period
# accumulated
# other
# comprehensive
# income
# beginning
# of
# period
# foreign
# currency
# translation
# fair
# market
# value
# of
# cash
# flow
# hedge
# unrealized
# loss
# 'LOSS' is negative
# on
# investments
# end
# of
# period
# retained
# earnings
# beginning
# of
# period
# net
# earnings
# preferred
# stock
# dividends
# paid
# series
# 'A' is neither positive nor negative
# per
# share
# series
# 'B' is neither positive nor negative
# per
# share
# end
# of
# period
# less
# treasury
# stock
# beginning
# and
# end
# of
# period
# less
# unearned
# employee
# stock
# ownership
# plan
# shares
# beginning
# of
# period
# purchase
# of
# shares
# repayments
# from
# loan
# end
# of
# year
# total
# stockholders
# equity
# the
# accompanying
# notes
# are
# an
# integral
# part
# of
# these
# consolidated
# financial
# statements
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# consolidated
# statements
# of
# comprehensive
# income
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# unaudited
# in
# thousands
# comprehensive
# income
# net
# earnings
# changes
# in
# other
# comprehensive
# income
# foreign
# currency
# translation
# fair
# market
# value
# of
# cash
# flow
# hedge
# unrealized
# gain
# 'GAIN' is positive
# loss
# 'LOSS' is negative
# on
# investments
# total
# comprehensive
# income
# the
# accompanying
# notes
# are
# an
# integral
# part
# of
# these
# consolidated
# financial
# statements
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# consolidated
# statements
# of
# earnings
# quarters
# ended
# 'DECEMBER' is neither positive nor negative
# unaudited
# in
# thousands
# except
# share
# and
# per
# share
# data
# revenues
# rental
# revenue
# net
# sales
# premiums
# net
# investment
# and
# interest
# income
# total
# revenues
# costs
# and
# expenses
# operating
# expenses
# cost
# of
# sales
# benefits
# and
# losses
# 'LOSSES' is negative
# amortization
# of
# deferred
# acquisition
# costs
# lease
# expense
# depreciation
# net
# total
# costs
# and
# expenses
# earnings
# from
# operations
# interest
# expense
# pretax
# earnings
# loss
# 'LOSS' is negative
# income
# tax
# benefit
# 'BENEFIT' is positive
# expense
# net
# earnings
# loss
# 'LOSS' is negative
# loss
# 'LOSS' is negative
# per
# common
# share
# both
# basic
# and
# diluted
# weighted
# average
# common
# shares
# outstanding
# the
# accompanying
# notes
# are
# an
# integral
# part
# of
# these
# consolidated
# financial
# statements
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# consolidated
# statements
# of
# cash
# flows
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# unaudited
# in
# thousands
# cash
# flows
# from
# operating
# activities
# net
# earnings
# depreciation
# and
# amortization
# provision
# for
# losses
# 'LOSSES' is negative
# on
# accounts
# receivable
# net
# gain
# 'GAIN' is positive
# on
# sale
# of
# real
# and
# personal
# property
# net
# gain
# 'GAIN' is positive
# loss
# 'LOSS' is negative
# on
# sale
# of
# investments
# changes
# in
# policy
# liabilities
# and
# accruals
# additions
# to
# deferred
# policy
# acquisition
# costs
# net
# change
# in
# other
# operating
# assets
# and
# liabilities
# net
# cash
# provided
# by
# operating
# activities
# cash
# flows
# from
# investing
# activities
# purchases
# of
# investments
# property
# plant
# and
# equipment
# fixed
# maturities
# common
# stock
# preferred
# stock
# mortgage
# loans
# proceeds
# from
# sale
# of
# investments
# property
# plant
# and
# equipment
# fixed
# maturities
# preferred
# stock
# real
# estate
# mortgage
# loans
# changes
# in
# other
# investments
# net
# cash
# used
# by
# investing
# activities
# cash
# flows
# from
# financing
# activities
# net
# change
# in
# shortterm
# borrowings
# proceeds
# from
# notes
# debt
# issuance
# costs
# leveraged
# employee
# stock
# ownership
# plan
# purchase
# of
# shares
# repayments
# from
# loan
# principal
# payments
# on
# notes
# repurchase
# of
# preferred
# stock
# net
# change
# in
# cash
# overdraft
# preferred
# stock
# dividends
# paid
# investment
# contract
# deposits
# investment
# contract
# withdrawals
# net
# cash
# used
# by
# financing
# activities
# increase
# decrease
# in
# cash
# and
# cash
# equivalents
# cash
# and
# cash
# equivalents
# at
# beginning
# of
# period
# cash
# and
# cash
# equivalents
# at
# end
# of
# period
# the
# accompanying
# notes
# are
# an
# integral
# part
# of
# these
# consolidated
# financial
# statements
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# 'DECEMBER' is neither positive nor negative
# march
# and
# 'DECEMBER' is neither positive nor negative
# unaudited
# summary
# of
# significant
# accounting
# policies
# organization
# 'AMERCO' is neither positive nor negative
# 'A' is neither positive nor negative
# 'NEVADA' is neither positive nor negative
# corporation
# 'AMERCO' is neither positive nor negative
# is
# the
# holding
# company
# for
# 'UHAUL' is neither positive nor negative
# international
# 'INC' is neither positive nor negative
# 'UHAUL' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# real
# estate
# company
# real
# estate
# republic
# western
# insurance
# company
# republic
# and
# oxford
# life
# insurance
# company
# oxford
# principles
# of
# consolidation
# the
# consolidated
# financial
# statements
# include
# the
# accounts
# of
# the
# parent
# corporation
# 'AMERCO' is neither positive nor negative
# and
# its
# whollyowned
# subsidiaries
# all
# material
# intercompany
# accounts
# and
# transactions
# of
# 'AMERCO' is neither positive nor negative
# and
# its
# subsidiaries
# have
# been
# eliminated
# the
# financial
# statements
# and
# notes
# are
# presented
# as
# permitted
# by
# form
# and
# do
# not
# contain
# certain
# information
# included
# in
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# annual
# financial
# statements
# and
# notes
# the
# consolidated
# balance
# sheet
# as
# of
# 'DECEMBER' is neither positive nor negative
# and
# the
# related
# consolidated
# statements
# of
# earnings
# for
# the
# three
# and
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# and
# the
# related
# consolidated
# statements
# of
# changes
# in
# stockholders
# equity
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# the
# consolidated
# statements
# of
# comprehensive
# income
# and
# cash
# flows
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# are
# unaudited
# in
# the
# opinion
# of
# management
# all
# adjustments
# necessary
# for
# 'A' is neither positive nor negative
# fair
# presentation
# of
# such
# financial
# statements
# have
# been
# included
# such
# adjustments
# consisted
# only
# of
# normal
# recurring
# items
# interim
# results
# are
# not
# necessarily
# indicative
# of
# results
# for
# 'A' is neither positive nor negative
# full
# year
# the
# operating
# results
# and
# financial
# position
# of
# 'AMERCOS' is neither positive nor negative
# consolidated
# insurance
# operations
# are
# determined
# on
# 'A' is neither positive nor negative
# one
# quarter
# lag
# 'LAG' is negative
# there
# were
# no
# effects
# related
# to
# intervening
# events
# which
# would
# materially
# affect
# the
# consolidated
# financial
# position
# or
# results
# of
# operations
# for
# the
# financial
# statements
# presented
# herein
# certain
# reclassifications
# have
# been
# made
# to
# the
# financial
# statements
# for
# the
# three
# and
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# to
# conform
# with
# the
# current
# year
# 'S' is neither positive nor negative
# presentation
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# investments
# 'A' is neither positive nor negative
# comparison
# of
# amortized
# cost
# to
# market
# for
# fixed
# maturities
# is
# as
# follows
# 'SEPTEMBER' is neither positive nor negative
# par
# value
# gross
# gross
# estimated
# consolidated
# or
# number
# amortized
# unrealized
# unrealized
# market
# 'HELDTOMATURITY' is neither positive nor negative
# of
# shares
# cost
# gains
# 'GAINS' is positive
# losses
# 'LOSSES' is negative
# value
# in
# thousands
# us
# treasury
# securities
# and
# government
# obligations
# us
# government
# agency
# mortgage
# backed
# securities
# obligations
# of
# states
# and
# political
# subdivisions
# corporate
# securities
# mortgagebacked
# securities
# redeemable
# preferred
# stocks
# 'SEPTEMBER' is neither positive nor negative
# par
# value
# gross
# gross
# estimated
# consolidated
# or
# number
# amortized
# unrealized
# unrealized
# market
# 'AVAILABLEFORSALE' is neither positive nor negative
# of
# shares
# cost
# gains
# 'GAINS' is positive
# losses
# 'LOSSES' is negative
# value
# in
# thousands
# us
# treasury
# securities
# and
# government
# obligations
# us
# government
# agency
# mortgage
# backed
# securities
# obligations
# of
# states
# and
# political
# subdivisions
# corporate
# securities
# mortgagebacked
# securities
# redeemable
# preferred
# stocks
# total
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# summarized
# consolidated
# financial
# information
# of
# insurance
# subsidiaries
# 'A' is neither positive nor negative
# summarized
# consolidated
# balance
# sheet
# for
# republic
# is
# presented
# below
# 'SEPTEMBER' is neither positive nor negative
# in
# thousands
# investments
# fixed
# maturities
# investments
# other
# receivables
# deferred
# policy
# acquisition
# costs
# due
# from
# affiliate
# deferred
# federal
# income
# taxes
# other
# assets
# total
# assets
# policy
# liabilities
# and
# accruals
# unearned
# premiums
# other
# policyholders
# funds
# and
# liabilities
# total
# liabilities
# stockholder
# 'S' is neither positive nor negative
# equity
# total
# liabilities
# and
# stockholder
# 'S' is neither positive nor negative
# equity
# 'A' is neither positive nor negative
# summarized
# consolidated
# income
# statement
# for
# republic
# is
# presented
# below
# quarter
# ended
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# 'SEPTEMBER' is neither positive nor negative
# in
# thousands
# premiums
# net
# investment
# income
# total
# revenue
# benefits
# and
# losses
# 'LOSSES' is negative
# amortization
# of
# deferred
# policy
# acquisition
# costs
# operating
# expenses
# total
# expenses
# income
# from
# operations
# federal
# income
# tax
# expense
# net
# income
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# summarized
# consolidated
# financial
# information
# of
# insurance
# subsidiaries
# continued
# 'A' is neither positive nor negative
# summarized
# consolidated
# balance
# sheet
# for
# oxford
# is
# presented
# below
# 'SEPTEMBER' is neither positive nor negative
# in
# thousands
# investments
# fixed
# maturities
# investments
# other
# receivables
# deferred
# policy
# acquisition
# costs
# due
# from
# to
# affiliate
# other
# assets
# total
# assets
# policy
# liabilities
# and
# accruals
# premium
# deposits
# other
# policyholders
# funds
# and
# liabilities
# deferred
# federal
# income
# taxes
# total
# liabilities
# stockholder
# 'S' is neither positive nor negative
# equity
# total
# liabilities
# and
# stockholder
# 'S' is neither positive nor negative
# equity
# 'A' is neither positive nor negative
# summarized
# consolidated
# income
# statement
# for
# oxford
# is
# presented
# below
# quarter
# ended
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# 'SEPTEMBER' is neither positive nor negative
# in
# thousands
# premiums
# net
# investment
# income
# total
# revenue
# benefits
# and
# losses
# 'LOSSES' is negative
# amortization
# of
# deferred
# policy
# acquisition
# costs
# operating
# expenses
# total
# expenses
# income
# from
# operations
# federal
# income
# tax
# expense
# net
# income
# in
# 'DECEMBER' is neither positive nor negative
# north
# 'AMERICAN' is neither positive nor negative
# fire
# casualty
# insurance
# company
# 'NAFCIC' is neither positive nor negative
# was
# sold
# to
# republic
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# accumulated
# other
# comprehensive
# income
# table
# 'A' is neither positive nor negative
# summary
# of
# accumulated
# comprehensive
# income
# components
# follows
# caption
# unrealized
# fair
# market
# accumulated
# foreign
# gain
# 'GAIN' is positive
# loss
# 'LOSS' is negative
# value
# of
# other
# currency
# on
# cash
# flow
# comprehensive
# translation
# investments
# hedge
# income
# in
# thousands
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# balance
# at
# march
# foreign
# currency
# translation
# fair
# market
# value
# of
# cash
# flow
# hedge
# net
# of
# taxes
# of
# unrealized
# gain
# 'GAIN' is positive
# loss
# 'LOSS' is negative
# on
# investments
# net
# of
# taxes
# of
# balance
# at
# 'DECEMBER' is neither positive nor negative
# balance
# at
# march
# foreign
# currency
# translation
# fair
# market
# value
# of
# cash
# flow
# hedge
# net
# of
# taxes
# of
# unrealized
# gain
# 'GAIN' is positive
# loss
# 'LOSS' is negative
# on
# investments
# net
# of
# taxes
# of
# balance
# at
# 'DECEMBER' is neither positive nor negative
# table
# contingent
# liabilities
# and
# commitments
# during
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# 'A' is neither positive nor negative
# subsidiary
# of
# 'UHAUL' is neither positive nor negative
# entered
# into
# fifteen
# transactions
# and
# has
# subsequently
# entered
# into
# one
# transaction
# whereby
# the
# subsidiary
# sold
# rental
# trucks
# and
# subsequently
# leased
# them
# back
# 'AMERCO' is neither positive nor negative
# has
# guaranteed
# of
# residual
# values
# at
# 'DECEMBER' is neither positive nor negative
# and
# an
# additional
# subsequent
# to
# 'DECEMBER' is neither positive nor negative
# for
# these
# assets
# at
# the
# end
# of
# the
# respective
# lease
# terms
# following
# are
# the
# lease
# commitments
# for
# the
# leases
# executed
# during
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# subsequently
# which
# have
# 'A' is neither positive nor negative
# term
# of
# more
# than
# one
# year
# in
# thousands
# net
# activity
# year
# ended
# lease
# subsequent
# to
# march
# commitments
# period
# end
# total
# thereafter
# in
# the
# normal
# course
# of
# business
# 'AMERCO' is neither positive nor negative
# is
# 'A' is neither positive nor negative
# defendant
# 'DEFENDANT' is negative
# in
# 'A' is neither positive nor negative
# number
# of
# suits
# and
# claims
# 'CLAIMS' is negative
# 'AMERCO' is neither positive nor negative
# is
# also
# 'A' is neither positive nor negative
# party
# to
# several
# administrative
# proceedings
# arising
# from
# state
# and
# local
# provisions
# that
# regulate
# the
# removal
# 'ANDOR' is neither positive nor negative
# cleanup
# of
# underground
# fuel
# storage
# tanks
# it
# is
# the
# opinion
# of
# management
# that
# none
# of
# such
# suits
# claims
# 'CLAIMS' is negative
# or
# proceedings
# involving
# 'AMERCO' is neither positive nor negative
# individually
# or
# in
# the
# aggregate
# are
# expected
# to
# result
# in
# 'A' is neither positive nor negative
# material
# loss
# 'LOSS' is negative
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# supplemental
# cash
# flows
# information
# the
# increase
# decrease
# in
# receivables
# inventories
# and
# accounts
# payable
# and
# accrued
# liabilities
# net
# of
# other
# operating
# and
# investing
# activities
# follows
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# in
# thousands
# receivables
# inventories
# accounts
# payable
# and
# accrued
# liabilities
# income
# taxes
# paid
# in
# cash
# amounted
# to
# and
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# interest
# paid
# in
# cash
# amounted
# to
# and
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# earnings
# per
# share
# table
# the
# following
# table
# reflects
# the
# calculation
# of
# the
# earnings
# per
# share
# caption
# weighted
# average
# common
# shares
# income
# outstanding
# per
# share
# numerator
# denominator
# amount
# in
# thousands
# except
# share
# and
# per
# share
# data
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# quarter
# ended
# 'DECEMBER' is neither positive nor negative
# loss
# 'LOSS' is negative
# from
# operations
# less
# dividends
# on
# preferred
# shares
# basic
# and
# diluted
# loss
# 'LOSS' is negative
# per
# common
# share
# quarter
# ended
# 'DECEMBER' is neither positive nor negative
# earnings
# from
# operations
# less
# dividends
# on
# preferred
# shares
# basic
# and
# diluted
# loss
# 'LOSS' is negative
# per
# common
# share
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# earnings
# from
# operations
# less
# dividends
# on
# preferred
# shares
# basic
# earnings
# per
# common
# share
# effect
# of
# dilutive
# securities
# series
# 'B' is neither positive nor negative
# preferred
# shares
# diluted
# earnings
# per
# common
# share
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# earnings
# from
# operations
# less
# dividends
# on
# preferred
# shares
# basic
# and
# diluted
# earnings
# per
# common
# share
# table
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# related
# parties
# during
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# subsidiaries
# of
# 'AMERCO' is neither positive nor negative
# held
# various
# senior
# and
# junior
# notes
# with
# sac
# holding
# corporation
# and
# its
# subsidiaries
# sac
# holdings
# the
# voting
# common
# stock
# of
# sac
# holdings
# is
# held
# by
# mark
# 'V' is neither positive nor negative
# 'SHOEN' is neither positive nor negative
# 'A' is neither positive nor negative
# major
# stockholder
# of
# 'AMERCO' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# subsidiaries
# received
# interest
# payments
# of
# and
# principal
# payments
# of
# from
# sac
# holdings
# during
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# the
# terms
# of
# the
# notes
# receivable
# with
# sac
# holdings
# are
# consistent
# with
# the
# terms
# of
# notes
# receivable
# held
# by
# 'UHAUL' is neither positive nor negative
# for
# other
# properties
# owned
# by
# unrelated
# parties
# and
# managed
# by
# 'UHAUL' is neither positive nor negative
# 'UHAUL' is neither positive nor negative
# currently
# manages
# the
# properties
# owned
# by
# sac
# holdings
# pursuant
# to
# 'A' is neither positive nor negative
# management
# agreement
# under
# which
# 'UHAUL' is neither positive nor negative
# receives
# 'A' is neither positive nor negative
# management
# fee
# equal
# to
# of
# the
# gross
# receipts
# from
# the
# properties
# management
# fees
# of
# and
# were
# received
# during
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# the
# management
# fee
# percentage
# is
# consistent
# with
# the
# fees
# received
# by
# 'UHAUL' is neither positive nor negative
# for
# other
# properties
# owned
# by
# unrelated
# parties
# and
# managed
# by
# 'UHAUL' is neither positive nor negative
# during
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# 'A' is neither positive nor negative
# subsidiary
# of
# 'AMERCO' is neither positive nor negative
# funded
# through
# 'A' is neither positive nor negative
# note
# receivable
# the
# purchase
# of
# properties
# and
# construction
# costs
# for
# sac
# holdings
# of
# approximately
# management
# believes
# that
# the
# foregoing
# transactions
# were
# consummated
# on
# terms
# equivalent
# to
# those
# that
# prevail
# in
# 'ARMSLENGTH' is neither positive nor negative
# transactions
# new
# accounting
# standards
# during
# fiscal
# year
# 'AMERCO' is neither positive nor negative
# adopted
# statement
# of
# financial
# accounting
# standards
# no
# accounting
# for
# derivative
# instruments
# and
# hedging
# activities
# as
# of
# 'DECEMBER' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# recorded
# an
# after
# tax
# adjustment
# of
# to
# accumulated
# other
# comprehensive
# income
# recognizing
# the
# fair
# value
# of
# derivatives
# designated
# as
# cash
# flow
# hedges
# 'AMERCO' is neither positive nor negative
# uses
# interest
# rate
# swap
# agreements
# to
# potentially
# mitigate
# the
# impact
# of
# changes
# in
# interest
# rates
# on
# its
# variable
# rate
# debt
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# recognized
# as
# interest
# income
# representing
# the
# ineffectiveness
# 'INEFFECTIVENESS' is negative
# of
# the
# cash
# flow
# hedging
# activity
# other
# pronouncements
# issued
# by
# the
# financial
# standards
# board
# with
# future
# effective
# 'EFFECTIVE' is positive
# dates
# are
# either
# not
# applicable
# or
# not
# material
# to
# the
# consolidated
# financial
# statements
# of
# 'AMERCO' is neither positive nor negative
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# industry
# segment
# and
# geographic
# area
# data
# industry
# segment
# data
# 'AMERCO' is neither positive nor negative
# has
# four
# industry
# segments
# represented
# by
# moving
# and
# storage
# operations
# 'UHAUL' is neither positive nor negative
# real
# estate
# property
# and
# casualty
# insurance
# republic
# and
# life
# insurance
# oxford
# table
# information
# concerning
# operations
# by
# industry
# segment
# follows
# caption
# moving
# property
# adjustments
# and
# storage
# real
# casualty
# life
# and
# operations
# estate
# insurance
# insurance
# eliminations
# consolidated
# in
# thousands
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# revenues
# outside
# intersegment
# total
# revenue
# depreciation
# amortization
# interest
# expense
# pretax
# earnings
# income
# tax
# identifiable
# assets
# table
# table
# caption
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# revenues
# outside
# intersegment
# total
# revenue
# depreciation
# amortization
# interest
# expense
# pretax
# earnings
# income
# tax
# identifiable
# assets
# table
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# industry
# segment
# and
# geographic
# area
# data
# continued
# table
# caption
# moving
# property
# adjustments
# and
# storage
# real
# casualty
# life
# and
# operations
# estate
# insurance
# insurance
# eliminations
# consolidated
# in
# thousands
# quarter
# ended
# 'DECEMBER' is neither positive nor negative
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# revenues
# outside
# intersegment
# total
# revenue
# depreciation
# amortization
# interest
# expense
# pretax
# earnings
# income
# tax
# table
# table
# caption
# quarter
# ended
# 'DECEMBER' is neither positive nor negative
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# revenues
# outside
# intersegment
# total
# revenue
# depreciation
# amortization
# interest
# expense
# pretax
# earnings
# income
# tax
# table
# table
# caption
# geographic
# area
# data
# united
# united
# all
# amounts
# are
# in
# states
# 'CANADA' is neither positive nor negative
# consolidated
# states
# 'CANADA' is neither positive nor negative
# consolidated
# us
# 'S' is neither positive nor negative
# nine
# months
# ended
# quarter
# ended
# in
# thousands
# 'DECEMBER' is neither positive nor negative
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# 'C' is neither positive nor negative
# total
# revenues
# depreciation
# amortization
# interest
# expense
# pretax
# earnings
# income
# tax
# identifiable
# assets
# 'NA' is neither positive nor negative
# 'NA' is neither positive nor negative
# 'NA' is neither positive nor negative
# 'DECEMBER' is neither positive nor negative
# total
# revenues
# depreciation
# amortization
# interest
# expense
# pretax
# earnings
# income
# tax
# identifiable
# assets
# 'NA' is neither positive nor negative
# 'NA' is neither positive nor negative
# 'NA' is neither positive nor negative
# table
# page
# 'AMERCO' is neither positive nor negative
# and
# consolidated
# subsidiaries
# notes
# to
# consolidated
# financial
# statements
# continued
# unaudited
# subsequent
# events
# on
# 'JANUARY' is neither positive nor negative
# the
# united
# states
# supreme
# court
# denied
# 'DENIED' is negative
# review
# of
# the
# bankruptcy
# 'BANKRUPTCY' is negative
# court
# 'S' is neither positive nor negative
# ruling
# that
# the
# plaintiffs
# 'PLAINTIFFS' is negative
# nonmanagement
# members
# of
# the
# 'SHOEN' is neither positive nor negative
# family
# and
# their
# affiliates
# are
# entitled
# to
# interest
# related
# to
# 'A' is neither positive nor negative
# previous
# resolution
# of
# 'A' is neither positive nor negative
# longstanding
# legal
# dispute
# 'DISPUTE' is negative
# involving
# the
# 'SHOEN' is neither positive nor negative
# family
# and
# related
# to
# control
# of
# 'AMERCO' is neither positive nor negative
# in
# 'AMERCO' is neither positive nor negative
# deposited
# approximately
# million
# into
# an
# escrow
# account
# to
# secure
# payment
# of
# the
# disputed
# 'DISPUTED' is negative
# interest
# pending
# final
# resolution
# of
# this
# issue
# the
# escrow
# account
# is
# reflected
# as
# 'A' is neither positive nor negative
# component
# of
# other
# assets
# in
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# consolidated
# financial
# statements
# the
# amount
# deposited
# into
# the
# escrow
# account
# will
# be
# transferred
# to
# the
# plaintiffs
# 'PLAINTIFFS' is negative
# in
# the
# near
# future
# the
# release
# of
# the
# escrow
# will
# not
# have
# the
# effect
# of
# increasing
# or
# decreasing
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# net
# earnings
# but
# will
# reduce
# stockholders
# equity
# on
# 'FEBRUARY' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# issued
# of
# senior
# notes
# due
# on
# 'FEBRUARY' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# declared
# 'A' is neither positive nor negative
# cash
# dividend
# of
# per
# preferred
# share
# to
# preferred
# stockholders
# of
# record
# as
# of
# 'FEBRUARY' is neither positive nor negative
# page
# item
# management
# 'S' is neither positive nor negative
# discussion
# and
# analysis
# of
# financial
# condition
# and
# results
# of
# operations
# forwardlooking
# statements
# this
# report
# contains
# forwardlooking
# statements
# additional
# written
# or
# oral
# forwardlooking
# statements
# may
# be
# made
# by
# 'AMERCO' is neither positive nor negative
# from
# time
# to
# time
# in
# filings
# with
# the
# securities
# and
# exchange
# commission
# or
# otherwise
# management
# believes
# such
# forwardlooking
# statements
# are
# within
# the
# meaning
# of
# the
# 'SAFEHARBOR' is neither positive nor negative
# provisions
# such
# statements
# may
# include
# but
# not
# be
# limited
# to
# projections
# of
# revenues
# income
# or
# loss
# 'LOSS' is negative
# estimates
# of
# capital
# expenditures
# plans
# for
# future
# operations
# products
# or
# services
# and
# financing
# needs
# or
# plans
# as
# well
# as
# assumptions
# relating
# to
# the
# foregoing
# the
# words
# believe
# expect
# anticipate
# estimate
# project
# and
# similar
# expressions
# identify
# forwardlooking
# statements
# which
# speak
# only
# as
# of
# the
# date
# the
# statement
# was
# made
# forwardlooking
# statements
# are
# inherently
# subject
# to
# risks
# and
# uncertainties
# some
# of
# which
# can
# not
# be
# predicted
# or
# quantified
# future
# events
# and
# actual
# results
# could
# differ
# materially
# from
# those
# set
# forth
# in
# contemplated
# by
# or
# underlying
# the
# forward
# looking
# statements
# the
# following
# disclosures
# as
# well
# as
# other
# statements
# in
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# report
# and
# in
# the
# notes
# to
# 'AMERCOS' is neither positive nor negative
# consolidated
# financial
# statements
# describe
# factors
# among
# others
# that
# could
# contribute
# to
# or
# cause
# such
# differences
# or
# that
# could
# affect
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# stock
# price
# general
# information
# on
# industry
# segments
# is
# incorporated
# by
# reference
# from
# item
# financial
# statements
# notes
# and
# of
# notes
# to
# consolidated
# financial
# statements
# the
# notes
# discuss
# the
# principles
# of
# consolidation
# summarized
# consolidated
# financial
# information
# and
# industry
# segment
# and
# geographical
# area
# data
# respectively
# in
# consolidation
# all
# intersegment
# premiums
# are
# eliminated
# and
# the
# benefits
# losses
# 'LOSSES' is negative
# and
# expenses
# are
# retained
# by
# the
# insurance
# companies
# results
# of
# operations
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# versus
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# moving
# and
# storage
# operations
# revenues
# consist
# of
# rental
# revenues
# and
# net
# sales
# total
# rental
# revenue
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# net
# revenues
# from
# the
# rental
# of
# moving
# related
# equipment
# increased
# by
# million
# this
# increase
# is
# primarily
# attributable
# to
# higher
# truck
# rental
# revenues
# the
# growth
# in
# truck
# rental
# revenue
# primarily
# reflects
# improved
# 'IMPROVED' is positive
# utilization
# an
# increase
# in
# the
# average
# revenue
# per
# transaction
# and
# higher
# truck
# rental
# inventory
# net
# sales
# revenues
# were
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# revenue
# growth
# from
# propane
# sales
# which
# was
# up
# by
# during
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# from
# the
# sale
# of
# moving
# support
# items
# 'IE' is neither positive nor negative
# boxes
# 'ETC' is neither positive nor negative
# which
# was
# up
# by
# during
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# led
# to
# the
# improvement
# 'IMPROVEMENT' is positive
# cost
# of
# sales
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# 'A' is neither positive nor negative
# higher
# sales
# volume
# contributed
# to
# the
# increase
# operating
# expenses
# before
# intercompany
# eliminations
# increased
# to
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# from
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# increased
# expenditure
# levels
# for
# rental
# equipment
# maintenance
# and
# personnel
# due
# to
# an
# increase
# in
# truck
# rental
# transactions
# and
# in
# fleet
# size
# were
# primarily
# responsible
# lease
# expense
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# this
# increase
# reflects
# additional
# leasing
# activity
# over
# the
# past
# twelve
# months
# net
# depreciation
# expense
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# was
# million
# as
# compared
# to
# million
# in
# the
# same
# period
# of
# the
# prior
# year
# the
# increase
# reflects
# an
# increase
# in
# depreciation
# recognized
# on
# the
# rental
# truck
# fleet
# page
# real
# estate
# operations
# rental
# revenue
# before
# intercompany
# eliminations
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# intercompany
# revenue
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# respectively
# net
# investment
# and
# interest
# income
# was
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# as
# compared
# to
# million
# during
# the
# same
# period
# of
# the
# prior
# year
# this
# increase
# correlates
# to
# 'A' is neither positive nor negative
# significant
# increase
# in
# average
# note
# and
# mortgage
# receivables
# outstanding
# operating
# expenses
# were
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# versus
# million
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# reduced
# building
# maintenance
# expense
# accounted
# for
# the
# majority
# of
# the
# decline
# 'DECLINE' is negative
# from
# the
# prior
# year
# lease
# expense
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# and
# was
# million
# and
# million
# respectively
# the
# increase
# reflects
# payments
# under
# 'A' is neither positive nor negative
# synthetic
# lease
# facility
# being
# utilized
# to
# develop
# storage
# properties
# net
# depreciation
# expense
# for
# the
# nine
# months
# ended
# 'DECEMBER' is neither positive nor negative
# was
# million
# as
# compared
# to
# million
# in
# the
# same
# period
# of
# the
# prior
# year
# the
# decrease
# reflects
# higher
# gains
# 'GAINS' is positive
# from
# the
# disposition
# of
# property
# and
# lower
# levels
# of
# depreciable
# assets
# property
# and
# casualty
# republic
# 'S' is neither positive nor negative
# premiums
# were
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# the
# decrease
# in
# premium
# for
# as
# compared
# to
# resulted
# from
# the
# 'UHAUL' is neither positive nor negative
# liability
# programs
# in
# the
# rental
# industry
# which
# decreased
# to
# million
# from
# million
# respectively
# this
# decrease
# resulted
# from
# the
# restructuring
# 'RESTRUCTURING' is negative
# of
# the
# 'UHAUL' is neither positive nor negative
# business
# auto
# general
# liability
# policy
# the
# deductible
# was
# changed
# at
# 'APRIL' is neither positive nor negative
# from
# 'A' is neither positive nor negative
# flat
# deductible
# to
# 'A' is neither positive nor negative
# deductible
# this
# reduced
# premiums
# by
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# as
# compared
# to
# the
# impact
# of
# this
# change
# will
# result
# in
# an
# overall
# savings
# of
# million
# in
# premium
# taxes
# for
# additionally
# assumed
# treaty
# reinsurance
# increased
# to
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# as
# compared
# to
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# direct
# multiple
# peril
# 'PERIL' is negative
# and
# general
# agency
# premium
# increased
# to
# million
# and
# million
# respectively
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# compared
# to
# million
# and
# million
# respectively
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# net
# investment
# income
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# the
# decrease
# from
# to
# is
# attributable
# to
# 'A' is neither positive nor negative
# decrease
# in
# invested
# assets
# and
# 'A' is neither positive nor negative
# lower
# yield
# on
# reinvested
# funds
# benefits
# and
# losses
# 'LOSSES' is negative
# were
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# the
# decrease
# from
# to
# resulted
# from
# 'A' is neither positive nor negative
# decrease
# in
# the
# 'UHAUL' is neither positive nor negative
# liability
# programs
# for
# unpaid
# 'UNPAID' is negative
# reported
# claims
# 'CLAIMS' is negative
# corresponding
# to
# the
# decrease
# in
# premiums
# mentioned
# above
# deferred
# acquisition
# costs
# 'DAC' is neither positive nor negative
# consist
# of
# commissions
# and
# other
# costs
# which
# vary
# with
# and
# are
# primarily
# related
# to
# the
# production
# of
# new
# business
# the
# prior
# year
# commissions
# and
# other
# related
# expenses
# are
# amortized
# over
# the
# following
# year
# the
# amortization
# expenses
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# were
# million
# and
# million
# respectively
# the
# increase
# from
# to
# is
# due
# mainly
# to
# republic
# 'S' is neither positive nor negative
# subsidiary
# company
# 'S' is neither positive nor negative
# 'DAC' is neither positive nor negative
# expense
# which
# increased
# to
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# from
# 'A' is neither positive nor negative
# negligible
# amount
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# also
# contributing
# was
# 'A' is neither positive nor negative
# million
# increase
# in
# the
# nonaffiliated
# agents
# expense
# the
# field
# underwriting
# and
# mobile
# home
# programs
# increased
# due
# to
# written
# and
# unearned
# premiums
# and
# the
# excess
# worker
# 'S' is neither positive nor negative
# compensation
# program
# increased
# due
# to
# commission
# expenses
# relating
# to
# 'A' is neither positive nor negative
# settlement
# agreement
# with
# the
# previous
# general
# agent
# operating
# expenses
# were
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# commissions
# decreased
# to
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# compared
# to
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# this
# is
# mainly
# attributable
# to
# republics
# subsidiary
# 'S' is neither positive nor negative
# 'DAC' is neither positive nor negative
# earned
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# this
# subsidiary
# was
# purchased
# in
# 'DECEMBER' is neither positive nor negative
# therefore
# there
# was
# no
# 'DAC' is neither positive nor negative
# included
# for
# this
# subsidiary
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# additionally
# there
# was
# an
# increase
# in
# the
# nonaffiliated
# agents
# and
# assumed
# treaty
# reinsurance
# 'DAC' is neither positive nor negative
# earned
# relating
# to
# the
# increase
# in
# the
# 'DAC' is neither positive nor negative
# expense
# mentioned
# above
# slightly
# offsetting
# were
# increased
# lease
# expenses
# of
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# all
# other
# underwriting
# expenses
# were
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# page
# operating
# profit
# before
# tax
# and
# intercompany
# elimination
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# this
# represents
# 'A' is neither positive nor negative
# decrease
# in
# of
# million
# from
# and
# resulted
# mainly
# from
# decreased
# premium
# revenue
# and
# investment
# income
# life
# insurance
# net
# premiums
# were
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# oxford
# realized
# premium
# increases
# in
# the
# areas
# of
# medicare
# supplement
# credit
# life
# and
# disability
# and
# single
# premium
# whole
# life
# insurance
# products
# oxford
# increased
# medicare
# supplement
# premium
# through
# the
# reinsurance
# of
# 'A' is neither positive nor negative
# block
# of
# policies
# and
# by
# adding
# direct
# premium
# through
# new
# programs
# these
# increased
# premiums
# by
# million
# oxford
# began
# marketing
# 'A' is neither positive nor negative
# new
# single
# premium
# whole
# life
# policy
# in
# this
# product
# accounted
# for
# million
# of
# new
# premiums
# in
# over
# with
# the
# sale
# of
# 'NAFCIC' is neither positive nor negative
# credit
# insurance
# premiums
# decreased
# by
# million
# as
# expected
# premiums
# decreases
# occurred
# in
# nonessential
# 'NAI' is neither positive nor negative
# lines
# that
# were
# terminated
# 'TERMINATED' is negative
# and
# due
# to
# fewer
# annuitizations
# these
# changes
# accounted
# for
# 'A' is neither positive nor negative
# million
# decrease
# in
# premiums
# through
# the
# first
# nine
# months
# of
# net
# investment
# income
# before
# intercompany
# eliminations
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# this
# increase
# is
# due
# to
# the
# increase
# in
# the
# average
# invested
# assets
# for
# the
# year
# which
# was
# the
# result
# of
# new
# premium
# in
# and
# the
# increased
# asset
# base
# from
# the
# acquisition
# of
# 'NAI' is neither positive nor negative
# and
# safe
# mate
# benefits
# incurred
# were
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# this
# increase
# is
# primarily
# due
# to
# medicare
# supplement
# benefits
# incurred
# these
# benefits
# are
# related
# to
# the
# new
# business
# recorded
# in
# the
# new
# medicare
# supplement
# reinsurance
# accounted
# for
# million
# of
# benefit
# 'BENEFIT' is positive
# variance
# annuity
# benefits
# combined
# with
# the
# elimination
# of
# 'NONFOCUSED' is neither positive nor negative
# 'NAI' is neither positive nor negative
# health
# lines
# reduced
# benefits
# by
# million
# amortization
# of
# 'DAC' is neither positive nor negative
# and
# the
# value
# of
# business
# acquired
# 'VOBA' is neither positive nor negative
# was
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# oxford
# defers
# commissions
# and
# other
# policy
# acquisition
# costs
# on
# single
# premium
# business
# these
# costs
# are
# amortized
# as
# the
# premium
# is
# earned
# over
# the
# term
# of
# the
# policy
# oxford
# continues
# to
# increase
# its
# single
# premium
# credit
# business
# in
# force
# 'FORCE' is negative
# thus
# increasing
# both
# the
# deferred
# costs
# on
# the
# balance
# ...
# combined
# with
# budgeted
# cash
# flow
# is
# adequate
# to
# meet
# periodic
# needs
# capital
# and
# operating
# budgets
# allow
# republic
# to
# schedule
# cash
# needs
# in
# accordance
# with
# investment
# and
# underwriting
# proceeds
# republic
# maintains
# 'A' is neither positive nor negative
# diversified
# securities
# investment
# portfolio
# primarily
# in
# bonds
# at
# varying
# maturity
# levels
# with
# of
# the
# fixed
# income
# securities
# consisting
# of
# investment
# grade
# securities
# the
# maturity
# distribution
# is
# designed
# to
# provide
# sufficient
# liquidity
# to
# meet
# future
# cash
# needs
# current
# liquidity
# remains
# strong
# 'STRONG' is positive
# with
# current
# invested
# assets
# equal
# to
# of
# total
# liabilities
# the
# liability
# for
# reported
# and
# unreported
# 'UNREPORTED' is negative
# losses
# 'LOSSES' is negative
# are
# based
# upon
# company
# historical
# and
# industry
# averages
# unpaid
# 'UNPAID' is negative
# loss
# 'LOSS' is negative
# adjustment
# expenses
# are
# based
# on
# historical
# ratios
# of
# loss
# 'LOSS' is negative
# adjustment
# expenses
# paid
# to
# losses
# 'LOSSES' is negative
# paid
# unpaid
# 'UNPAID' is negative
# loss
# 'LOSS' is negative
# and
# loss
# 'LOSS' is negative
# expenses
# are
# not
# discounted
# stockholder
# 'S' is neither positive nor negative
# equity
# was
# million
# and
# million
# at
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# republic
# considers
# current
# stockholder
# 'S' is neither positive nor negative
# equity
# to
# be
# adequate
# to
# support
# future
# growth
# and
# absorb
# unforeseen
# 'UNFORESEEN' is negative
# risk
# events
# republic
# does
# not
# use
# debt
# or
# equity
# issues
# to
# increase
# capital
# and
# therefore
# has
# no
# exposure
# to
# capital
# market
# conditions
# page
# life
# insurance
# oxford
# 'S' is neither positive nor negative
# primary
# sources
# of
# cash
# are
# premiums
# receipts
# from
# 'INTERESTSENSITIVE' is neither positive nor negative
# products
# and
# investment
# income
# the
# primary
# uses
# of
# cash
# are
# operating
# costs
# and
# benefit
# 'BENEFIT' is positive
# payments
# to
# policyholders
# matching
# the
# investment
# portfolio
# to
# the
# cash
# flow
# demands
# of
# the
# types
# of
# insurance
# being
# written
# is
# an
# important
# consideration
# benefit
# 'BENEFIT' is positive
# and
# claim
# statistics
# are
# continually
# monitored
# to
# provide
# projections
# of
# future
# cash
# requirements
# cash
# flows
# provided
# by
# operating
# activities
# were
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# cash
# flows
# provided
# used
# by
# financing
# activities
# were
# approximately
# million
# and
# million
# for
# the
# nine
# months
# ended
# 'SEPTEMBER' is neither positive nor negative
# and
# respectively
# cash
# flows
# from
# deferred
# annuity
# sales
# increase
# investment
# contract
# deposits
# which
# are
# 'A' is neither positive nor negative
# component
# of
# financing
# activities
# as
# well
# as
# the
# purchase
# of
# fixed
# maturities
# which
# are
# 'A' is neither positive nor negative
# component
# of
# investing
# activities
# the
# decrease
# in
# cash
# flows
# provided
# by
# financing
# activities
# for
# the
# first
# nine
# months
# of
# compared
# to
# the
# first
# nine
# months
# of
# is
# due
# to
# lower
# ratio
# of
# annuity
# deposits
# to
# withdrawals
# in
# addition
# to
# cash
# flows
# from
# operating
# and
# financing
# activities
# 'A' is neither positive nor negative
# substantial
# amount
# of
# liquid
# funds
# is
# available
# through
# oxford
# 'S' is neither positive nor negative
# shortterm
# portfolio
# at
# 'SEPTEMBER' is neither positive nor negative
# and
# short
# term
# investments
# were
# million
# and
# million
# respectively
# management
# believes
# that
# the
# overall
# sources
# of
# liquidity
# will
# continue
# to
# meet
# foreseeable
# cash
# needs
# stockholder
# 'S' is neither positive nor negative
# equity
# of
# oxford
# decreased
# to
# million
# in
# from
# million
# in
# the
# decrease
# is
# 'A' is neither positive nor negative
# result
# of
# the
# unrealized
# losses
# 'LOSSES' is negative
# on
# the
# available
# for
# sale
# investment
# portfolio
# oxford
# did
# not
# pay
# dividends
# in
# or
# applicable
# laws
# and
# regulations
# of
# the
# state
# of
# 'ARIZONA' is neither positive nor negative
# require
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# insurance
# subsidiaries
# to
# maintain
# minimum
# capital
# and
# surplus
# determined
# in
# accordance
# with
# statutory
# accounting
# practices
# with
# respect
# to
# oxford
# the
# amount
# is
# in
# addition
# the
# amount
# of
# dividends
# that
# can
# be
# paid
# to
# shareholders
# by
# insurance
# companies
# domiciled
# in
# the
# state
# of
# 'ARIZONA' is neither positive nor negative
# is
# limited
# any
# dividend
# in
# excess
# of
# the
# limit
# requires
# prior
# regulatory
# approval
# statutory
# surplus
# which
# can
# be
# distributed
# as
# dividends
# without
# regulatory
# approval
# is
# million
# at
# 'SEPTEMBER' is neither positive nor negative
# these
# restrictions
# are
# not
# expected
# to
# have
# 'A' is neither positive nor negative
# material
# adverse
# 'ADVERSE' is negative
# effect
# on
# the
# ability
# of
# 'AMERCO' is neither positive nor negative
# to
# meet
# its
# cash
# obligations
# consolidated
# group
# during
# each
# of
# the
# fiscal
# years
# ended
# march
# and
# 'UHAUL' is neither positive nor negative
# estimates
# gross
# capital
# expenditures
# will
# average
# approximately
# million
# primarily
# reflecting
# rental
# fleet
# rotation
# this
# level
# of
# capital
# expenditures
# combined
# with
# an
# average
# of
# approximately
# million
# in
# annual
# longterm
# debt
# maturities
# during
# this
# same
# period
# are
# expected
# to
# create
# annual
# average
# funding
# needs
# of
# approximately
# million
# management
# estimates
# that
# 'UHAUL' is neither positive nor negative
# will
# fund
# of
# these
# requirements
# with
# internally
# generated
# funds
# including
# proceeds
# from
# the
# disposition
# of
# older
# trucks
# and
# other
# asset
# sales
# credit
# agreements
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# operations
# are
# funded
# by
# various
# credit
# and
# financing
# arrangements
# including
# unsecured
# longterm
# borrowings
# unsecured
# 'MEDIUMTERM' is neither positive nor negative
# notes
# and
# revolving
# lines
# of
# credit
# with
# domestic
# and
# foreign
# banks
# principally
# to
# finance
# its
# fleet
# of
# trucks
# and
# trailers
# 'AMERCO' is neither positive nor negative
# routinely
# enters
# into
# sale
# and
# leaseback
# transactions
# as
# of
# 'DECEMBER' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# had
# million
# in
# total
# notes
# and
# loans
# payable
# outstanding
# and
# unutilized
# lines
# of
# credit
# of
# approximately
# million
# certain
# of
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# credit
# agreements
# contain
# restrictive
# financial
# and
# other
# covenants
# including
# among
# others
# covenants
# with
# respect
# to
# incurring
# additional
# indebtedness
# maintaining
# certain
# financial
# ratios
# and
# placing
# certain
# additional
# liens
# on
# its
# properties
# and
# assets
# at
# 'DECEMBER' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# was
# in
# compliance
# with
# these
# covenants
# 'AMERCO' is neither positive nor negative
# is
# further
# restricted
# in
# the
# issuance
# of
# certain
# types
# of
# preferred
# stock
# 'AMERCO' is neither positive nor negative
# is
# prohibited
# from
# issuing
# shares
# of
# preferred
# stock
# that
# provide
# for
# any
# mandatory
# redemption
# sinking
# fund
# payment
# or
# mandatory
# prepayment
# or
# that
# allow
# the
# holders
# thereof
# to
# require
# 'AMERCO' is neither positive nor negative
# or
# any
# subsidiary
# of
# 'AMERCO' is neither positive nor negative
# to
# repurchase
# such
# preferred
# stock
# at
# the
# option
# of
# such
# holders
# or
# upon
# the
# occurrence
# of
# any
# event
# or
# events
# without
# the
# consent
# of
# its
# lenders
# reference
# is
# made
# to
# note
# of
# notes
# to
# consolidated
# financial
# statements
# in
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# annual
# report
# on
# form
# for
# the
# fiscal
# year
# ended
# march
# for
# additional
# information
# about
# the
# credit
# agreements
# page
# year
# disclosure
# in
# preparation
# for
# any
# potential
# year
# processing
# problems
# 'PROBLEMS' is negative
# 'AMERCO' is neither positive nor negative
# worked
# since
# to
# identify
# any
# changes
# necessary
# to
# its
# existing
# computerized
# business
# systems
# to
# make
# these
# systems
# compliant
# for
# year
# processing
# 'AMERCO' is neither positive nor negative
# has
# spent
# approximately
# million
# to
# date
# in
# its
# year
# compliance
# efforts
# since
# 'JANUARY' is neither positive nor negative
# 'AMERCO' is neither positive nor negative
# has
# been
# assessing
# its
# information
# technology
# systems
# and
# has
# found
# no
# major
# year
# processing
# problems
# 'PROBLEMS' is negative
# page
# item
# quantitative
# and
# qualitative
# disclosures
# about
# market
# risk
# reference
# is
# made
# to
# part
# 'II' is neither positive nor negative
# item
# quantitative
# and
# qualitative
# disclosure
# about
# market
# risk
# in
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# annual
# report
# on
# form
# for
# the
# fiscal
# year
# ended
# march
# page
# part
# 'II' is neither positive nor negative
# other
# information
# item
# legal
# proceedings
# on
# 'JUNE' is neither positive nor negative
# five
# current
# 'ANDOR' is neither positive nor negative
# former
# moving
# center
# general
# managers
# 'GMS' is neither positive nor negative
# and
# one
# area
# field
# manager
# 'AFM' is neither positive nor negative
# filed
# suit
# in
# 'MARIN' is neither positive nor negative
# county
# superior
# 'SUPERIOR' is positive
# court
# case
# no
# 'BC' is neither positive nor negative
# entitled
# 'SARAH' is neither positive nor negative
# 'SAUNDERS' is neither positive nor negative
# 'ET' is neither positive nor negative
# 'AL' is neither positive nor negative
# 'VS' is neither positive nor negative
# 'UHAUL' is neither positive nor negative
# company
# of
# 'CALIFORNIA' is neither positive nor negative
# 'INC' is neither positive nor negative
# claiming
# 'CLAIMING' is negative
# that
# they
# were
# entitled
# to
# be
# compensated
# for
# all
# overtime
# hours
# worked
# in
# excess
# of
# forty
# hours
# per
# week
# in
# addition
# these
# plaintiffs
# 'PLAINTIFFS' is negative
# sought
# class
# action
# status
# purporting
# 'PURPORTING' is negative
# to
# represent
# all
# persons
# employed
# in
# 'CALIFORNIA' is neither positive nor negative
# as
# either
# 'A' is neither positive nor negative
# salaried
# 'GM' is neither positive nor negative
# or
# 'AFM' is neither positive nor negative
# since
# 'SEPTEMBER' is neither positive nor negative
# on
# 'SEPTEMBER' is neither positive nor negative
# 'A' is neither positive nor negative
# virtually
# identical
# lawsuit
# was
# filed
# in
# 'LOS' is neither positive nor negative
# 'ANGELES' is neither positive nor negative
# county
# superior
# 'SUPERIOR' is positive
# court
# case
# no
# 'BC' is neither positive nor negative
# entitled
# 'WYATT' is neither positive nor negative
# 'CRANDALL' is neither positive nor negative
# 'VS' is neither positive nor negative
# 'UHAUL' is neither positive nor negative
# international
# 'INC' is neither positive nor negative
# and
# 'UHAUL' is neither positive nor negative
# 'CO' is neither positive nor negative
# of
# 'CALIFORNIA' is neither positive nor negative
# this
# action
# did
# not
# include
# 'AFMS' is neither positive nor negative
# but
# did
# purport
# 'PURPORT' is negative
# to
# be
# brought
# on
# behalf
# of
# 'GMS' is neither positive nor negative
# and
# 'GM' is neither positive nor negative
# trainees
# these
# cases
# were
# consolidated
# by
# the
# court
# in
# 'LOS' is neither positive nor negative
# 'ANGELES' is neither positive nor negative
# on
# 'OCTOBER' is neither positive nor negative
# on
# 'JUNE' is neither positive nor negative
# plaintiff
# 'PLAINTIFF' is negative
# 'S' is neither positive nor negative
# motion
# to
# certify
# the
# 'AFMS' is neither positive nor negative
# as
# 'A' is neither positive nor negative
# class
# was
# denied
# 'DENIED' is negative
# and
# the
# motion
# to
# certify
# the
# 'GMS' is neither positive nor negative
# as
# 'A' is neither positive nor negative
# class
# was
# granted
# notice
# of
# class
# certification
# was
# mailed
# on
# or
# about
# august
# the
# class
# 'OPTOUT' is neither positive nor negative
# period
# ended
# on
# 'OCTOBER' is neither positive nor negative
# trial
# is
# set
# for
# 'JULY' is neither positive nor negative
# management
# does
# not
# expect
# the
# plaintiffs
# 'PLAINTIFFS' is negative
# damage
# 'DAMAGE' is negative
# claims
# 'CLAIMS' is negative
# to
# result
# in
# 'A' is neither positive nor negative
# material
# loss
# 'LOSS' is negative
# to
# 'AMERCO' is neither positive nor negative
# reference
# is
# made
# to
# part
# 'I' is neither positive nor negative
# item
# business
# in
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# annual
# report
# on
# form
# for
# the
# fiscal
# year
# ended
# march
# for
# 'A' is neither positive nor negative
# discussion
# of
# certain
# environmental
# proceedings
# page
# item
# exhibits
# and
# reports
# on
# form
# 'A' is neither positive nor negative
# exhibits
# exhibit
# no
# description
# restated
# 'RESTATED' is negative
# articles
# of
# incorporation
# restated
# 'RESTATED' is negative
# bylaws
# of
# 'AMERCO' is neither positive nor negative
# as
# of
# august
# senior
# indenture
# dated
# 'APRIL' is neither positive nor negative
# senior
# supplemental
# indenture
# dated
# 'FEBRUARY' is neither positive nor negative
# financial
# data
# schedule
# 'B' is neither positive nor negative
# reports
# on
# form
# 'A' is neither positive nor negative
# report
# on
# form
# was
# filed
# on
# 'FEBRUARY' is neither positive nor negative
# in
# connection
# with
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# issuance
# of
# of
# notes
# due
# incorporated
# by
# reference
# to
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# quarterly
# report
# on
# form
# for
# the
# quarter
# ended
# 'DECEMBER' is neither positive nor negative
# file
# no
# incorporated
# by
# reference
# to
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# quarterly
# report
# on
# form
# for
# the
# quarter
# ended
# 'DECEMBER' is neither positive nor negative
# file
# no
# incorporated
# by
# reference
# to
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# current
# report
# on
# form
# dated
# 'APRIL' is neither positive nor negative
# file
# no
# incorporated
# by
# reference
# to
# 'AMERCO' is neither positive nor negative
# 'S' is neither positive nor negative
# current
# report
# on
# form
# dated
# 'FEBRUARY' is neither positive nor negative
# file
# no
# page
# signatures
# pursuant
# to
# the
# requirements
# of
# the
# securities
# exchange
# act
# of
# the
# registrant
# has
# duly
# caused
# this
# report
# to
# be
# signed
# on
# its
# behalf
# by
# the
# undersigned
# thereunto
# duly
# authorized
# 'AMERCO' is neither positive nor negative
# registrant
# dated
# 'FEBRUARY' is neither positive nor negative
# by
# 'S' is neither positive nor negative
# 'GARY' is neither positive nor negative
# 'B' is neither positive nor negative
# 'HORTON' is neither positive nor negative
# 'GARY' is neither positive nor negative
# 'B' is neither positive nor negative
# 'HORTON' is neither positive nor negative
# treasurer
# principal
# financial
# officer
# text
# document
# document
# type
# sequence
# description
# 'FDS' is neither positive nor negative
# text
# table
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# article
# legend
# this
# schedule
# contains
# summary
# financial
# information
# extracted
# from
# form
# 'DECEMBER' is neither positive nor negative
# and
# is
# qualified
# in
# its
# entirety
# by
# reference
# to
# such
# financial
# statements
# legend
# multiplier
# 'S' is neither positive nor negative
# 'C' is neither positive nor negative
# 'PERIODTYPE' is neither positive nor negative
# 'FISCALYEAREND' is neither positive nor negative
# 'PERIODEND' is neither positive nor negative
# cash
# securities
# receivables
# allowances
# inventory
# 'CURRENTASSETS' is neither positive nor negative
# 'PP' is neither positive nor negative
# 'E' is neither positive nor negative
# depreciation
# 'TOTALASSETS' is neither positive nor negative
# 'CURRENTLIABILITIES' is neither positive nor negative
# bonds
# 'PREFERREDMANDATORY' is neither positive nor negative
# preferred
# common
# 'OTHERSE' is neither positive nor negative
# 'TOTALLIABILITYANDEQUITY' is neither positive nor negative
# sales
# 'TOTALREVENUES' is neither positive nor negative
# 'CGS' is neither positive nor negative
# 'TOTALCOSTS' is neither positive nor negative
# 'OTHEREXPENSES' is neither positive nor negative
# 'LOSSPROVISION' is neither positive nor negative
# 'INTERESTEXPENSE' is neither positive nor negative
# 'INCOMEPRETAX' is neither positive nor negative
# 'INCOMETAX' is neither positive nor negative
# 'INCOMECONTINUING' is neither positive nor negative
# discontinued
# 'DISCONTINUED' is negative
# extraordinary
# changes
# 'NETINCOME' is neither positive nor negative
# 'EPSBASIC' is neither positive nor negative
# 'EPSDILUTED' is neither positive nor negative
# 'FN' is neither positive nor negative
# the
# value
# for
# receivables
# represents
# their
# amount
# net
# of
# their
# allowances
# an
# unclassified
# balance
# sheet
# exists
# in
# the
# registrant
# 'S' is neither positive nor negative
# financial
# statements
# 'FN' is neither positive nor negative
# table
# text
# document
# 'SECDOCUMENT' is neither positive nor negative
# end
# 'PRIVACYENHANCED' is neither positive nor negative
# message
# Positive Score: 27
# Negative Score: -100

# %%
df1.iloc[0]['Positive'].isNull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-fa5b5db34cd5> in <module>()
# ----> 1 df1.iloc[0]['Positive'].isNull()
#
# AttributeError: 'numpy.float64' object has no attribute 'isNull'

# %%
import math

# %%
math.isnan(df1.iloc[0]['Positive'])
# Out:
# True
